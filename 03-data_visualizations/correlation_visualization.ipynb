# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
from definitions import *
import cv2
from triangles import TRIANGLES

# %%
users_aggregated_data = pd.read_csv("./aggregated_data.csv", index_col=0)

# %%
def generate_sactter(x,y):
    plt.scatter(users_aggregated_data[x],users_aggregated_data[y])
    plt.title("Correlação " + str(x)+"-"+str(y))
    plt.xlabel(str(x))
    plt.ylabel(str(y))
    plt.savefig("./correlation_visualizations/"+str(x)+"-"+str(y)+".png",dpi = 1000)

# %% [markdown]
# ## 05-00_2  X  asrsb_score

# %%
generate_sactter("05-00_2","asrsb_score")

# %% [markdown]
# ## 05-01_2 X asrsb_score

# %%
generate_sactter("05-01_2","asrsb_score")

# %% [markdown]
# ## bai_score X srq_score

# %%
generate_sactter("bai_score" , "srq_score")
